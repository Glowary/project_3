# %%
import pandas as pd

# Replace this with your CSV file path
csv_file_path = '/Users/greenboi/ComputerScience/Python/project_3/data/updatedsaleprice.csv'

# Read the CSV file
updated_real_estate_data = pd.read_csv(csv_file_path)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
from pymongo import MongoClient
from connection import connection_string

# Replace with your MongoDB connection string
conn_string = connection_string

# Create a MongoClient to the running mongod instance
client = MongoClient(conn_string)

# Select the database and collection
db = client['RealEstateDatabase']
collection = db['RealEstateCollection']

# %%
# Convert DataFrame to dictionary
data_dict = updated_real_estate_data.to_dict("records")

# Insert collection
collection.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('6577c0b9e9da59917c16fac8'), ObjectId('6577c0b9e9da59917c16fac9'), ObjectId('6577c0b9e9da59917c16faca'), ObjectId('6577c0b9e9da59917c16facb'), ObjectId('6577c0b9e9da59917c16facc'), ObjectId('6577c0b9e9da59917c16facd'), ObjectId('6577c0b9e9da59917c16face'), ObjectId('6577c0b9e9da59917c16facf'), ObjectId('6577c0b9e9da59917c16fad0'), ObjectId('6577c0b9e9da59917c16fad1'), ObjectId('6577c0b9e9da59917c16fad2'), ObjectId('6577c0b9e9da59917c16fad3'), ObjectId('6577c0b9e9da59917c16fad4'), ObjectId('6577c0b9e9da59917c16fad5'), ObjectId('6577c0b9e9da59917c16fad6'), ObjectId('6577c0b9e9da59917c16fad7'), ObjectId('6577c0b9e9da59917c16fad8'), ObjectId('6577c0b9e9da59917c16fad9'), ObjectId('6577c0b9e9da59917c16fada'), ObjectId('6577c0b9e9da59917c16fadb'), ObjectId('6577c0b9e9da59917c16fadc'), ObjectId('6577c0b9e9da59917c16fadd'), ObjectId('6577c0b9e9da59917c16fade'), ObjectId('6577c0b9e9da59917c16fadf'), ObjectId('6577c0b9e9da59917c16fae0'), ObjectId('6577c0b9e9da59917c16
# ...

# %%
group_csv_file_path = '/Users/greenboi/ComputerScience/Python/project_3/data/group.csv'
group_data = pd.read_csv(group_csv_file_path)

collection2 = db['GroupCollection']

group_data_dict = group_data.to_dict("records")
collection2.insert_many(group_data_dict)
# Out:
# InsertManyResult([ObjectId('6577c155e9da59917c16fce5'), ObjectId('6577c155e9da59917c16fce6'), ObjectId('6577c155e9da59917c16fce7'), ObjectId('6577c155e9da59917c16fce8'), ObjectId('6577c155e9da59917c16fce9'), ObjectId('6577c155e9da59917c16fcea'), ObjectId('6577c155e9da59917c16fceb'), ObjectId('6577c155e9da59917c16fcec'), ObjectId('6577c155e9da59917c16fced'), ObjectId('6577c155e9da59917c16fcee'), ObjectId('6577c155e9da59917c16fcef'), ObjectId('6577c155e9da59917c16fcf0'), ObjectId('6577c155e9da59917c16fcf1'), ObjectId('6577c155e9da59917c16fcf2'), ObjectId('6577c155e9da59917c16fcf3'), ObjectId('6577c155e9da59917c16fcf4'), ObjectId('6577c155e9da59917c16fcf5'), ObjectId('6577c155e9da59917c16fcf6'), ObjectId('6577c155e9da59917c16fcf7'), ObjectId('6577c155e9da59917c16fcf8'), ObjectId('6577c155e9da59917c16fcf9'), ObjectId('6577c155e9da59917c16fcfa'), ObjectId('6577c155e9da59917c16fcfb'), ObjectId('6577c155e9da59917c16fcfc'), ObjectId('6577c155e9da59917c16fcfd'), ObjectId('6577c155e9da59917c16
# ...
